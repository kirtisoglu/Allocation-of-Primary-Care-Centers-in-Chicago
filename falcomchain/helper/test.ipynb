# %%
from falcomchain.helper import DataHandler
from falcomchain.helper import Plotter

# %%
# Example Usage

handler = DataHandler()
chicago = handler.load_chicago()
graph = handler.load_graph()



map = Plotter(blocks=chicago, graph=graph)

map.plot()

# %%
from falcomchain.helper import DataHandler, export_graph_with_coords
handler = DataHandler()
graph = handler.load_graph()

# %%
from falcomchain.helper import DataHandler, export_graph_with_coords
handler = DataHandler()
graph = handler.load_graph()

path = "/Users/kirtisoglu/Documents/Documents/GitHub/Allocation-of-Primary-Care-Centers-in-Chicago/data/processed/graphh.json"

export_graph_with_coords(graph, path)
